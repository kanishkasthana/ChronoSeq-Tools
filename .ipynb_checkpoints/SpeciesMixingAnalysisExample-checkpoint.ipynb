# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
human_df=pd.read_table("N701.aligned.sorted.merged.tagged.HUMAN_ONLY.dge.txt.gz")

# %%
human_vector=human_df.iloc[:,1:].sum()
with pd.option_context('display.max_rows', None, 'display.max_columns', None): 
    print(human_vector[0:100])
# Out:
# CTGTCTCTTATA       43
# GGCGACCTTGAA    38619
# TCGTTATAGCCA    45559
# TAGCGATCTCCG    45824
# CCACTACCCATA    30055
# CAAGCCGTCAGA    31929
# CAAAAGCAGAGT    25714
# CAGCGGCATAAA    17478
# AGCGCATAAAGA    23311
# GCCAGGGGAGCC    25524
# CATGAAGCCCGA    22564
# CGCCACTTGGGA    22876
# GCTATAATCTTG    22613
# ATAAGGTACCGT    17769
# ACACCGACTTCC    18733
# CTTTTCCCACAC      451
# TGTCTCTTATAC       21
# GCAATTTCGCTC    17049
# CGGCTGAATTTC    19772
# CACACCAGGTCA    18544
# GCCTGCTTAACG      604
# CCTCTACACACC      552
# TCGGCGCGCGCG    23294
# TGGGGAGTGGAT    21101
# ACGGCCTCGACA      474
# CGTGTGCCGCGG    23823
# GTGCGATAGCCT    14933
# GGGCTTCGCGAA    11609
# CCTCTAATTCCG    14523
# CAGTCCCCAGGG    16108
# ACGAGGCCCTCG    15744
# CTAGAAACCCCA     6805
# CCAGTCGCCCCT    13457
# CCGGTGGACCAG    14824
# GACGGAGTCGAA    13599
# CCAATTTTCAGA    18303
# ATCAGTATAGCC    12528
# ACGAGTGAGGAT    12283
# GGAAGCATATTA    11108
# GGCACGATGGGT    17135
# ACTCACAATTCC    13495
# ...

# %%
mouse_df=pd.read_table("N701.aligned.sorted.merged.tagged.MOUSE_ONLY.dge.txt.gz")

# %%
mouse_vector=mouse_df.iloc[:,1:].sum()
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(mouse_vector[0:100])
# Out:
# CTGTCTCTTATA       20
# GGCGACCTTGAA      856
# TCGTTATAGCCA      858
# TAGCGATCTCCG      880
# CCACTACCCATA      591
# CAAGCCGTCAGA      613
# CAAAAGCAGAGT      538
# CAGCGGCATAAA     9384
# AGCGCATAAAGA     5042
# GCCAGGGGAGCC      608
# CATGAAGCCCGA      476
# CGCCACTTGGGA      499
# GCTATAATCTTG      446
# ATAAGGTACCGT     6097
# ACACCGACTTCC      488
# CTTTTCCCACAC    16626
# TGTCTCTTATAC        1
# GCAATTTCGCTC      350
# CGGCTGAATTTC      479
# CACACCAGGTCA      471
# GCCTGCTTAACG    19894
# CCTCTACACACC    17422
# TCGGCGCGCGCG      505
# TGGGGAGTGGAT      319
# ACGGCCTCGACA    14945
# CGTGTGCCGCGG      471
# GTGCGATAGCCT      380
# GGGCTTCGCGAA     6884
# CCTCTAATTCCG      423
# CAGTCCCCAGGG      332
# ACGAGGCCCTCG      406
# CTAGAAACCCCA     8308
# CCAGTCGCCCCT      388
# CCGGTGGACCAG      357
# GACGGAGTCGAA      280
# CCAATTTTCAGA      744
# ATCAGTATAGCC     6465
# ACGAGTGAGGAT      272
# GGAAGCATATTA      233
# GGCACGATGGGT      273
# ACTCACAATTCC      376
# ...

# %%
fig, ax = plt.subplots(figsize=(8,8))
ax.scatter(mouse_vector,human_vector)
'''
point1=[0,0]
point2=[10000,200000]
point3=[200000,10000]
x_values = [point1[0], point2[0]]
y_values = [point1[1], point2[1]]
ax.plot(x_values,y_values, 'r--')
x_values = [point1[0], point3[0]]
y_values = [point1[1], point3[1]]
ax.plot(x_values,y_values,'g--')
'''
plt.xlabel("MOUSE TRANSCRIPTS")
plt.ylabel("HUMAN TRANSCRIPTS")
plt.title("SPECIES MIXING PLOT for 13 Cycles")
plt.xlim([0,20000])
plt.ylim([0,20000])
fig = plt.gcf()
fig.savefig("Species_mixing_13Cycles.svg")
